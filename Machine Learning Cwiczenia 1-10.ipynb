# %% [markdown]
# <a href="https://colab.research.google.com/github/simpsone4652/data_science/blob/main/Machine%20Learning%20Cwiczenia%201-10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

# tutaj wpisz rozwiązanie

# %%
df = pd.DataFrame(data)
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
df.isnull().sum()
# Out:
# size      1
# color     0
# gender    1
# price     1
# weight    2
# bought    0
# dtype: int64

# %%
percent_missing = df.isnull().sum()  / len(df)
print(round(percent_missing,2))
# Out:
# size      0.17
# color     0.00
# gender    0.17
# price     0.17
# weight    0.33
# bought    0.00
# dtype: float64

# %% [markdown]
# Ćwiczenie 2

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)
# tutaj wpisz rozwiązanie
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
df['weight'] = imp_mean.fit_transform(df[['weight']])
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %% [markdown]
# Cwiczenie 3

# %%
data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
df[['weight']] = imputer.fit_transform(df[['weight']])
# tutaj wpisz rozwiązanie
print(imputer.statistics_[0])
# Out:
# 415.0

# %% [markdown]
# Cwiczenie 4

# %%
imp_stal = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value=99.0)
df[['price']] = imp_stal.fit_transform(df[['price']])
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN   99.0   300.0    yes
# 3  NaN  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %% [markdown]
# Cwiczenie 5

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
df['size']=imputer.fit_transform(df[['size']])
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN   99.0   300.0    yes
# 3    M  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %% [markdown]
# Cwiczenie 6

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)
# tutaj wpisz rozwiązanie
check_for_nan = df['weight'].isnull().values.any()
print(df[~df['weight']].isnull().mean())
# Out:
# 0.3333333333333333

# %% [markdown]
# Cwiczenie 7

# %%
df_object = df.select_dtypes(include='object').fillna('empty')
df_object
# Out:
#     size  color  gender bought
# 0     XL    red  female    yes
# 1      L  green    male     no
# 2      M   blue   empty    yes
# 3  empty  green  female     no
# 4      M    red  female    yes
# 5      M  green    male     no

# %% [markdown]
# Cwiczenie 8

# %%
df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})
df['weight'] = pd.cut(df['weight'],bins=3)
df
# Out:
#              weight
# 0  (67.977, 75.667]
# 1  (75.667, 83.333]
# 2    (83.333, 91.0]
# 3    (83.333, 91.0]
# 4    (83.333, 91.0]
# 5  (75.667, 83.333]
# 6  (67.977, 75.667]

# %% [markdown]
# Cwiczenie 9

# %%
df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})
df['weight_cut'] = pd.cut(df['weight'],bins=[60,75,80,95])
df
# Out:
#    weight weight_cut
# 0    75.0   (60, 75]
# 1    78.5   (75, 80]
# 2    85.0   (80, 95]
# 3    91.0   (80, 95]
# 4    84.5   (80, 95]
# 5    83.0   (80, 95]
# 6    68.0   (60, 75]

# %% [markdown]
# Cwiczenie 10

# %%
df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})
df['weight_cut'] = pd.cut(df['weight'],bins = [60,75,80,95],labels=['light','normal','heavy'])
df
# Out:
#    weight weight_cut
# 0    75.0      light
# 1    78.5     normal
# 2    85.0      heavy
# 3    91.0      heavy
# 4    84.5      heavy
# 5    83.0      heavy
# 6    68.0      light
